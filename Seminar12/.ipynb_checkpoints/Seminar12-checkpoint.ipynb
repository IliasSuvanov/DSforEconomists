# %% [markdown]
# ## Drawing distributions by hand

# %%
import seaborn as sns
import numpy as np
import pandas as pd
math = np.random.randint(1, 6, size=10)
english = np.random.randint(1,6, size=10)
chinese = np.random.randint(1,6, size=10)
japanese = np.random.randint(1,6, size =10)
names = ["Alex", "Joe", "Doe", "Foe", "Roy", "Toy", "Joy", "Zoe","Loi","Koi"]

# %%
df = pd.DataFrame({'alex':[2,2,3,4],'john':[3,5,5,5]},\
                  index = ['math','english','chinese','japanese'])
df.head()
# Out:
#           alex  john
# math         2     3
# english      2     5
# chinese      3     5
# japanese     4     5

# %%
marks = {z[0]:z[1:] for z in zip(names, math, chinese, japanese,english)}

# %%
df = pd.DataFrame(marks, index = ['math','japanese', 'chinese','english'])

# %%
df.head()
# Out:
#           Alex  Joe  Doe  Foe  Roy  Toy  Joy  Zoe  Loi  Koi
# math         2    5    2    1    4    3    3    4    1    1
# japanese     5    1    3    4    3    3    4    4    5    4
# chinese      5    2    4    5    1    2    4    4    1    2
# english      4    5    4    2    5    4    4    3    2    1

# %%
sns.set_theme()
sns.displot(df.loc['math'], binwidth =1)
sns.displot(df.loc['japanese'], binwidth =1)

# %% [markdown]
# ## Empirical cumulative distributions
# This plot draws a monotonically-increasing curve through each datapoint such that the height of the curve reflects the proportion of observations with a smaller value:

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm", kind="ecdf")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", kind="ecdf")

# %% [markdown]
# ## Visualizing bivariate distributions
# All of the examples so far have considered univariate distributions: distributions of a single variable, perhaps conditional on a second variable assigned to hue. Assigning a second variable to y, however, will plot a bivariate distribution:

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm")

# %% [markdown]
# A bivariate histogram bins the data within rectangles that tile the plot and then shows the count of observations within each rectangle with the fill color (analagous to a heatmap()). Similarly, a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian. The default representation then shows the contours of the 2D density:

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", binwidth=(2, .5))

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", binwidth=(2, .5), cbar=True)

# %%
tips = sns.load_dataset("tips")
sns.displot(tips, x="size", y="tip")

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %% [markdown]
# Similar to displot(), setting a different kind="kde" in jointplot() will change both the joint and marginal plots the use kdeplot():

# %%
sns.jointplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="species",
    kind="kde"
)

# %% [markdown]
# A less-obtrusive way to show marginal distributions uses a “rug” plot, which adds a small tick on the edge of the plot to represent each individual observation. This is built into displot():

# %%
sns.displot(
    penguins, x="bill_length_mm", y="bill_depth_mm",
    kind="kde", rug=True
)

# %% [markdown]
# jointplot() is a convenient interface to the JointGrid class, which offeres more flexibility when used directly:

# %%
g = sns.JointGrid(data=penguins, x="bill_length_mm", y="bill_depth_mm")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
